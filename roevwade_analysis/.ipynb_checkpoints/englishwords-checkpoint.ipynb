# %%
pip install english-words
# Out:
# Collecting english-words
#   Downloading english-words-1.1.0.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.1 MB/s eta 0:00:01
# Building wheels for collected packages: english-words
#   Building wheel for english-words (setup.py) ... done
#   Created wheel for english-words: filename=english_words-1.1.0-py3-none-any.whl size=1106679 sha256=37a318b88e4befa2dbc6632640b93fd312610330a01a9896a1b292d7efc65612
#   Stored in directory: /Users/gabbypinto/Library/Caches/pip/wheels/25/3d/4c/12a119ce90b46b4f90f9ddf41d719ecabb40faec6103379fc8
# Successfully built english-words
# Installing collected packages: english-words
# Successfully installed english-words-1.1.0
# WARNING: You are using pip version 21.1.2; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/gabbypinto/.pyenv/versions/3.7.4/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from english_words import english_words_set
import nltk

# %%
count = 0
words = []
for word in english_words_set:
#     print(nltk.pos_tag(word))
    if len(word) == 5:
        words.append(word)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-dd85e7ad44de> in <module>
#       2 words = []
#       3 for word in english_words_set:
# ----> 4     print(nltk.pos_tag(word))
#       5     if len(word) == 5:
#       6         words.append(word)
#
# ~/.pyenv/versions/3.7.4/lib/python3.7/site-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     163     """
#     164     tagger = _get_tagger(lang)
# --> 165     return _pos_tag(tokens, tagset, tagger, lang)
#     166
#     167
#
# ~/.pyenv/versions/3.7.4/lib/python3.7/site-packages/nltk/tag/__init__.py in _pos_tag(tokens, tagset, tagger, lang)
#     117     # Throws Error if tokens is of string type
#     118     elif isinstance(tokens, str):
# --> 119         raise TypeError('tokens: expected a list of strings, got a string')
#     120
#     121     else:
#
# TypeError: tokens: expected a list of strings, got a string

# %%
print(words)
# Out:
# ['silly', 'grunt', 'chasm', 'Colby', 'retch', 'swoop', 'axiom', 'Beebe', 'bossy', 'reach', 'which', 'cinch', 'Margo', 'exalt', 'unify', 'while', 'troll', 'aisle', 'loess', 'multi', 'gassy', 'Nubia', 'inter', 'testy', 'abase', 'Alvin', 'vacua', 'ducat', 'silky', 'alert', 'scout', 'flair', 'elder', 'aloft', 'Alcoa', 'lemur', 'Galen', 'gusty', 'angle', 'Dixon', 'field', 'knelt', 'buteo', 'adept', 'jowly', 'stilt', 'Fahey', 'doubt', 'angry', 'Timon', 'heavy', 'nymph', 'pushy', 'Piotr', 'amort', 'Delia', 'strip', 'yearn', 'cacti', 'pizza', 'annum', 'hyper', 'shako', 'Errol', 'bater', 'Julie', 'whelk', 'Ervin', 'gorse', 'Artie', 'weedy', 'sharp', 'douce', 'Isaac', 'tight', 'blood', 'Perez', 'Felix', 'morel', 'chard', 'Kevin', 'Xhosa', 'Selma', 'monel', 'brook', 'horse', 'prick', 'dulse', 'groom', 'Missy', 'chalk', 'ankle', 'dairy', 'smash', 'blast', 'Wolff', 'flack', 'baggy', 'eucre', 'taxon', "won't", 'rivet', 'feast', 'Elton', 'fifth', 'larva', 'quota', 'lymph', 'Carib', 'Verdi', 'nasty', 'eager', 'quell', 'anvil', 'hilum', 'giant', 'worry', 'beech', 'tacky', 'order', 'hatch', 'tying', 'krill', 'Knott', 'mossy', 'geode', 'barge', 'umbra', 'briar', 'lathe', 'urine', 'showy', 'shuck', 'Tracy', 'Meiji', 'spurn', 'entry', 'chunk', 'smirk', 'squat', 'light', 'brash', 'surah', 'relic', 'count', 'breve', 'route', 'Clint', 'assay', 'soapy', 'Durer', 'Babel', 'corny', 'price', 'cameo', 'Eagan', 'hitch', 'misty', 'easel', 'slide', 'hairy', 'swipe', 'Steen', 'triad', 'avian', 'Aires', 'erect', 'Kenya', 'okapi', 'beryl', 'upend', 'stark', 'metal', 'strum', 'birth', 'query', 'rhyme', 'whisk', 'stuff', 'spilt', 'sibyl', 'spunk', 'bloom', 'somal', 'gaffe', 'Mecca', 'leery', 'Wyeth', 'ghoul', 'frail', 'frank', 'aroma', 'algae', 'bloke', 'atone', 'blunt', 'Jason', 'Kline', 'geese', 'Seton', 'egret', 'sieve', 'slate', 'stove', 'Huber', 'large', 'louse', 'devil', 'clump', 'lucky', 'Louis', 'awake', 'crank', 'money', 'glade', 'Edwin', 'strap', 'Caine', 'stole', 'biota', 'putty', 'Elsie', 'Lenin', 'foggy', 'stiff', 'washy', 'fight', 'green', 'lunge', 'Jacob', 'Irwin', 'cubic', 'Croix', 'proto', 'abyss', 'sheet', 'snare', 'joust', 'Payne', 'munch', "he'll", 'purge', 'Keith', 'soggy', 'faint', 'skulk', 'build', 'amble', 'roast', 'Morse', 'hough', 'tinge', 'tally', 'Merck', 'snafu', 'refer', 'Burke', 'Pliny', 'Plato', 'conic', 'fraud', 'Decca', 'trace', 'spend', 'bruit', 'cheap', 'snail', 'Biggs', 'POBox', 'mylar', 'nifty', 'bathe', 'Welch', 'motif', 'liken', 'Wendy', 'idiot', 'stoop', 'patio', 'pinch', 'royal', 'Hobbs', 'nudge', 'carob', 'Yaqui', 'Prado', 'wally', 'breed', 'drake', 'Kidde', 'savvy', 'mocha', 'Levis', 'weigh', 'rondo', 'biddy', 'gloat', 'width', 'remit', 'taper', 'velar', 'Susan', 'batik', 'begin', 'flake', 'loamy', 'Porte', 'otter', 'skull', 'messy', 'Berea', 'teach', 'Hines', 'befog', 'Caleb', 'Klein', 'suave', 'Oscar', 'round', 'cozen', 'sonny', 'novel', 'final', 'Libra', 'Niobe', 'bulky', 'matte', 'tecum', 'petal', 'Riley', 'spoof', 'bravo', 'nomad', 'lumen', 'sinus', 'kodak', 'enemy', 'begat', 'lusty', 'clomp', 'whelm', 'viral', 'flown', 'shell', 'Holst', 'franc', 'burly', 'cater', 'gibby', 'wrath', 'Wolfe', 'Asher', 'Peale', 'groin', 'usage', 'cabal', 'Sybil', 'stagy', 'samba', 'slash', 'sixty', 'sneak', 'Krebs', 'igloo', 'howdy', 'plain', 'proof', 'fever', 'agent', 'styli', 'equip', "we're", 'laden', 'first', 'James', 'stair', 'vetch', 'Qatar', 'ileum', 'Davis', 'Haydn', 'crash', 'lying', 'shown', 'Molly', 'nodal', 'Topsy', 'robot', 'begun', 'brine', 'tilde', 'cagey', 'badge', 'flora', 'heart', 'choke', 'pivot', 'boggy', 'Pabst', 'Greek', 'acute', 'drank', 'Ababa', 'butch', 'drain', 'spook', 'hydro', 'shyly', 'heave', 'saint', 'faery', 'Erich', 'carve', 'walla', 'felon', 'Moser', 'chine', 'chute', 'elope', 'black', 'Miami', 'Deere', 'rouse', 'pedal', 'Heinz', 'sonic', 'Aleck', 'lefty', 'bigot', 'Idaho', 'bacon', 'runic', 'marsh', 'Ethan', 'sushi', 'allow', 'Stahl', 'tansy', 'drawl', 'swarm', 'Clyde', 'buddy', 'sepia', 'shore', 'bo ...
