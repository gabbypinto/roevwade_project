# %% [markdown]
# ### Used for combining all tweets together into one csv file

# %%
import pandas as pd

# %%
df = pd.concat(
    map(pd.read_csv, ['/Users/gabbypinto/Desktop/roevwade_tweets/batch1_data/data_8_14.csv', '/Users/gabbypinto/Desktop/roevwade_tweets/batch1_data/data_8_19.csv','/Users/gabbypinto/Desktop/roevwade_tweets/batch1_data/data_8_19_v2.csv','/Users/gabbypinto/Desktop/roevwade_tweets/batch1_data/data_8_19_v3.csv']), ignore_index=True)
print(df)

df.to_csv("batch1.csv")
# Out:
# /Users/gabbypinto/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (0,3,5,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                    author id                 created_at geo  \
# 0                  594845016  2022-04-27 23:59:53+00:00
# 1                 3238197455  2022-04-27 23:59:32+00:00
# 2        1505086603118923777  2022-04-27 23:59:30+00:00
# 3        1505094121954115586  2022-04-27 23:59:29+00:00
# 4        1248533457996677121  2022-04-27 23:59:23+00:00
# ...                      ...                        ...  ..
# 3182832             36969470  2022-05-16 00:00:03+00:00
# 3182833           1688828623  2022-05-16 00:00:03+00:00
# 3182834             50434933  2022-05-16 00:00:03+00:00
# 3182835  1453768848163889154  2022-05-16 00:00:01+00:00
# 3182836             30783425  2022-05-16 00:00:00+00:00
#
# ...

# %%
#batch 2

df = pd.concat(
    map(pd.read_csv, ['/Users/gabbypinto/Desktop/roevwade_tweets/batch2_data/data_9_23.csv','/Users/gabbypinto/Desktop/roevwade_tweets/batch2_data/data_9_24.csv']), ignore_index=True)
print(df)

df.to_csv("batch2.csv")
# Out:
#                    author id                 created_at geo  \
# 0         945025799970795526  2022-05-21 23:59:56+00:00
# 1                  515767837  2022-05-21 23:59:51+00:00
# 2         805854889154744320  2022-05-21 23:59:50+00:00
# 3        1176724585221251072  2022-05-21 23:59:47+00:00
# 4         738763886216634368  2022-05-21 23:59:46+00:00
# ...                      ...                        ...  ..
# 1224117            976901094  2022-06-09 00:00:03+00:00
# 1224118            242374336  2022-06-09 00:00:02+00:00
# 1224119             21139887  2022-06-09 00:00:01+00:00
# 1224120  1387681375604547590  2022-06-09 00:00:01+00:00
# 1224121   808742550261600257  2022-06-09 00:00:00+00:00
#
#                           id lang  like_count  quote_count  reply_count  \
# 0        1528163717241872386   pt           0            0            0
# 1        1528163696077307904   en           0            0            0
# ...

# %%
#batch 3

df = pd.concat(
    map(pd.read_csv, ['/Users/gabbypinto/Desktop/roevwade_tweets/batch3_data/data_batch3_v2.csv','/Users/gabbypinto/Desktop/roevwade_tweets/batch3_data/data_batch3.csv']), ignore_index=True)
print(df)

df.to_csv("batch3.csv")
# Out:
#                    author id                 created_at geo  \
# 0                   67206826  2022-06-14 23:59:58+00:00
# 1                  157053660  2022-06-14 23:59:57+00:00
# 2                  264614699  2022-06-14 23:59:57+00:00
# 3        1229262408922759168  2022-06-14 23:59:53+00:00
# 4         744824831913263104  2022-06-14 23:59:51+00:00
# ...                      ...                        ...  ..
# 1956091             50434933  2022-06-30 20:42:14+00:00
# 1956092            748523910  2022-06-30 20:42:14+00:00
# 1956093  1362902092130750465  2022-06-30 20:42:14+00:00
# 1956094  1014639028262535168  2022-06-30 20:42:14+00:00
# 1956095           2763852002  2022-06-30 20:42:14+00:00
#
#                           id lang  like_count  quote_count  reply_count  \
# 0        1536861031925940228   en           0            0            0
# 1        1536861029921177601   en           0            0            0
# ...

# %%
#more

df = pd.concat(
    map(pd.read_csv, ['/Users/gabbypinto/Desktop/roevwade_tweets/more/data.csv','/Users/gabbypinto/Desktop/roevwade_tweets/more/data2.csv','/Users/gabbypinto/Desktop/roevwade_tweets/more/data3.csv']), ignore_index=True)
print(df)

df.to_csv("extra.csv")
# Out:
#                    author id                 created_at geo  \
# 0        1235421144905285632  2022-05-09 23:59:59+00:00
# 1                   22283928  2022-05-09 23:59:59+00:00
# 2         835339459709153280  2022-05-09 23:59:59+00:00
# 3                    2988601  2022-05-09 23:59:59+00:00
# 4         849411796171620352  2022-05-09 23:59:59+00:00
# ...                      ...                        ...  ..
# 3748506  1207860810845802497  2022-05-06 03:37:54+00:00
# 3748507   897895526720446465  2022-05-06 03:37:54+00:00
# 3748508  1449417831188078593  2022-05-06 03:37:54+00:00
# 3748509           1411726710  2022-05-06 03:37:54+00:00
# 3748510  1259124193729417221  2022-05-06 03:37:54+00:00
#
#                           id lang  like_count  quote_count  reply_count  \
# 0        1523815076322545664   en           0            0            0
# 1        1523815076058214401   en         163            3            2
# ...

# %%
#combine everything into one file

df = pd.concat(
    map(pd.read_csv, ['batch1.csv','batch2.csv','batch3.csv','extra.csv']), ignore_index=True)
print(df)

df.to_csv("allTweets.csv")
# Out:
# /Users/gabbypinto/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          Unnamed: 0              author id                 created_at geo  \
# 0                 0              594845016  2022-04-27 23:59:53+00:00
# 1                 1             3238197455  2022-04-27 23:59:32+00:00
# 2                 2    1505086603118923777  2022-04-27 23:59:30+00:00
# 3                 3    1505094121954115586  2022-04-27 23:59:29+00:00
# 4                 4    1248533457996677121  2022-04-27 23:59:23+00:00
# ...             ...                    ...                        ...  ..
# 11138468    3748506  1207860810845802496.0  2022-05-06 03:37:54+00:00
# 11138469    3748507   897895526720446464.0  2022-05-06 03:37:54+00:00
# 11138470    3748508  1449417831188078592.0  2022-05-06 03:37:54+00:00
# ...
